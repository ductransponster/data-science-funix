# %% [markdown]
# # Project Overview
#
# You receive a European Soccer Database that has more than 25,000 matches and more than 10,000 players for European professional soccer seasons from 2008 to 2016. The goal is you walk through this database to do analysis include some steps for exploring our dataset, some steps for basics statistics and then you visualize the result. To complete all your steps, you need to query your data in the database using SQL statement. This project practices you write SQL command to pull data and extract it.

# %% [markdown]
# # Database Description
#
# This European Soccer Database has more than 25,000 matches and more than 10,000 players for European professional soccer seasons from 2008 to 2016, 11 European Countries with their lead championship. Players and Teams' attributes sourced from EA Sports' FIFA video game series, including the weekly updates.

# %% [markdown]
# # Import Python package

# %%
#Import libraries
import numpy as np
import pandas as pd
import sqlite3
from datetime import timedelta
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 100)

# %% [markdown]
# ## Question 1: Connect to database and get information of all tables
#
# Read https://docs.python.org/2/library/sqlite3.html
#
# You write only SQL statement to get the result, should not use Pandas to manipulate result.

# %%
#Connect to database 
conn = sqlite3.connect('database.sqlite')

#and get information of all tables
tables = pd.read_sql("""SELECT *
                          FROM sqlite_master
                         WHERE type = 'table';""", conn)
tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# 7  CREATE TABLE `Team_Attributes` (\n\t`id`\tINTE...

# %% [markdown]
# ## Question 2: Select data in "Country" table

# %%
result_2 = pd.read_sql("SELECT * FROM Country;", conn)
result_2
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %% [markdown]
# ## Question 3: Select data in "League" table

# %%
result_3 = pd.read_sql("SELECT * FROM League;", conn)
result_3
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %% [markdown]
# ## Question 4: Select League data with country information
# The League table has relation with Country table by country_id. Use the join sql statement to join two tables.

# %%
result_4 = pd.read_sql("""SELECT l.name AS league,
                                 c.name AS country
                            FROM League AS l
                            JOIN Country AS c
                              ON l.country_id = c.id;""", conn)
result_4
# Out:
#                       league      country
# 0     Belgium Jupiler League      Belgium
# 1     England Premier League      England
# 2             France Ligue 1       France
# 3      Germany 1. Bundesliga      Germany
# 4              Italy Serie A        Italy
# 5     Netherlands Eredivisie  Netherlands
# 6         Poland Ekstraklasa       Poland
# 7   Portugal Liga ZON Sagres     Portugal
# 8    Scotland Premier League     Scotland
# 9            Spain LIGA BBVA        Spain
# 10  Switzerland Super League  Switzerland

# %% [markdown]
# ## Question 5: Select data from _Match_ table
# - When a team is serving as host of a contest, it is designated as the "home team". The opposing team is said to be the "away
# team"
# - In Match table, each row is a match with one home team and one away team including home team goal and away team goal respectively

# %%
result_5 = pd.read_sql("SELECT * FROM Match;", conn)
result_5
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 0            492473              9987              9993               1
# 1            492474             10000              9994               0
# 2            492475              9984              8635               0
# 3            492476              9991              9998               5
# 4            492477              7947              9985               1
# ...             ...               ...               ...             ...
# 25974       1992091             10190             10191               1
# 25975       1992092              9824             10199               1
# 25976       1992093              9956             10179               2
# 25977       1992094              7896             10243               0
# 25978       1992095             10192              9931               4
#
#        away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# 0                   1             NaN             NaN             NaN
# 1                   0             NaN             NaN             NaN
# 2                   3             NaN             NaN             NaN
# 3                   0             NaN             NaN             NaN
# 4                   3             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974               0             1.0             2.0             4.0
# 25975               2             1.0             3.0             5.0
# 25976               0             1.0             2.0             4.0
# 25977               0             1.0             2.0             4.0
# 25978               3             1.0             2.0             4.0
#
#        home_player_X4  home_player_X5  home_player_X6  home_player_X7  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             6.0             8.0             4.0             6.0
# 25975             7.0             2.0             4.0             6.0
# 25976             6.0             8.0             4.0             6.0
# 25977             6.0             8.0             3.0             7.0
# 25978             6.0             8.0             2.0             4.0
#
#        home_player_X8  home_player_X9  home_player_X10  home_player_X11  \
# 0                 NaN             NaN              NaN              NaN
# 1                 NaN             NaN              NaN              NaN
# 2                 NaN             NaN              NaN              NaN
# 3                 NaN             NaN              NaN              NaN
# 4                 NaN             NaN              NaN              NaN
# ...               ...             ...              ...              ...
# 25974             3.0             5.0              7.0              5.0
# 25975             8.0             5.0              4.0              6.0
# 25976             3.0             5.0              7.0              5.0
# 25977             5.0             3.0              5.0              7.0
# 25978             6.0             8.0              4.0              6.0
#
#        away_player_X1  away_player_X2  away_player_X3  away_player_X4  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             1.0             2.0             4.0             6.0
# 25975             1.0             2.0             4.0             6.0
# 25976             1.0             2.0             4.0             6.0
# 25977             1.0             2.0             4.0             6.0
# 25978             1.0             2.0             4.0             6.0
#
#        away_player_X5  away_player_X6  away_player_X7  away_player_X8  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             8.0             4.0             6.0             3.0
# 25975             8.0             3.0             5.0             7.0
# 25976             8.0             4.0             6.0             3.0
# 25977             8.0             4.0             6.0             3.0
# 25978             8.0             4.0             6.0             3.0
#
#        away_player_X9  away_player_X10  away_player_X11  home_player_Y1  \
# 0                 NaN              NaN              NaN             NaN
# 1                 NaN              NaN              NaN             NaN
# 2                 NaN              NaN              NaN             NaN
# 3                 NaN              NaN              NaN             NaN
# 4                 NaN              NaN              NaN             NaN
# ...               ...              ...              ...             ...
# 25974             5.0              7.0              5.0             1.0
# 25975             3.0              5.0              7.0             1.0
# 25976             5.0              7.0              5.0             1.0
# 25977             5.0              7.0              5.0             1.0
# 25978             5.0              7.0              5.0             1.0
#
#        home_player_Y2  home_player_Y3  home_player_Y4  home_player_Y5  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             3.0             3.0             3.0             3.0
# 25975             3.0             3.0             3.0             7.0
# 25976             3.0             3.0             3.0             3.0
# 25977             3.0             3.0             3.0             3.0
# 25978             3.0             3.0             3.0             3.0
#
#        home_player_Y6  home_player_Y7  home_player_Y8  home_player_Y9  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             6.0             6.0             8.0             8.0
# 25975             7.0             7.0             7.0             9.0
# 25976             6.0             6.0             8.0             8.0
# 25977             7.0             7.0             7.0            10.0
# 25978             7.0             7.0             7.0             7.0
#
#        home_player_Y10  home_player_Y11  away_player_Y1  away_player_Y2  \
# 0                  NaN              NaN             NaN             NaN
# 1                  NaN              NaN             NaN             NaN
# 2                  NaN              NaN             NaN             NaN
# 3                  NaN              NaN             NaN             NaN
# 4                  NaN              NaN             NaN             NaN
# ...                ...              ...             ...             ...
# 25974              8.0             11.0             1.0             3.0
# 25975             11.0             11.0             1.0             3.0
# 25976              8.0             11.0             1.0             3.0
# 25977             10.0             10.0             1.0             3.0
# 25978             10.0             10.0             1.0             3.0
#
#        away_player_Y3  away_player_Y4  away_player_Y5  away_player_Y6  ...  \
# 0                 NaN             NaN             NaN             NaN  ...
# 1                 NaN             NaN             NaN             NaN  ...
# 2                 NaN             NaN             NaN             NaN  ...
# 3                 NaN             NaN             NaN             NaN  ...
# 4                 NaN             NaN             NaN             NaN  ...
# ...               ...             ...             ...             ...  ...
# 25974             3.0             3.0             3.0             6.0  ...
# 25975             3.0             3.0             3.0             7.0  ...
# 25976             3.0             3.0             3.0             6.0  ...
# 25977             3.0             3.0             3.0             6.0  ...
# 25978             3.0             3.0             3.0             6.0  ...
#
#        home_player_11  away_player_1  away_player_2  away_player_3  \
# 0                 NaN            NaN            NaN            NaN
# 1                 NaN            NaN            NaN            NaN
# 2                 NaN            NaN            NaN            NaN
# 3                 NaN            NaN            NaN            NaN
# 4                 NaN            NaN            NaN            NaN
# ...               ...            ...            ...            ...
# 25974        195215.0       462944.0       563066.0         8800.0
# 25975         37257.0        42276.0       114792.0       150007.0
# 25976        289472.0        10637.0        67349.0       202663.0
# 25977        178142.0       274776.0       121080.0       197757.0
# 25978         71764.0       156175.0        95216.0       172768.0
#
#        away_player_4  away_player_5  away_player_6  away_player_7  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974        67304.0       158253.0       133126.0       186524.0
# 25975       178119.0        27232.0       570830.0       260708.0
# 25976        32597.0       114794.0       188114.0        25840.0
# 25977       260964.0       231614.0       113235.0        41116.0
# 25978        22834.0       458806.0       207234.0        25772.0
#
#        away_player_8  away_player_9  away_player_10  away_player_11  goal  \
# 0                NaN            NaN             NaN             NaN  None
# 1                NaN            NaN             NaN             NaN  None
# 2                NaN            NaN             NaN             NaN  None
# 3                NaN            NaN             NaN             NaN  None
# 4                NaN            NaN             NaN             NaN  None
# ...              ...            ...             ...             ...   ...
# 25974        93223.0       121115.0        232110.0        289732.0  None
# 25975       201704.0        36382.0         34082.0         95257.0  None
# 25976       482200.0        95230.0        451335.0        275122.0  None
# 25977       462608.0        42262.0         92252.0        194532.0  None
# 25978        40274.0        34035.0         41726.0        527103.0  None
#
#        shoton  shotoff  foulcommit  card  cross  corner  possession  B365H  \
# 0        None     None        None  None   None    None        None   1.73
# 1        None     None        None  None   None    None        None   1.95
# 2        None     None        None  None   None    None        None   2.38
# 3        None     None        None  None   None    None        None   1.44
# 4        None     None        None  None   None    None        None   5.00
# ...       ...      ...         ...   ...    ...     ...         ...    ...
# 25974    None     None        None  None   None    None        None    NaN
# 25975    None     None        None  None   None    None        None    NaN
# 25976    None     None        None  None   None    None        None    NaN
# 25977    None     None        None  None   None    None        None    NaN
# 25978    None     None        None  None   None    None        None    NaN
#
#        B365D  B365A   BWH   BWD   BWA   IWH  IWD  IWA   LBH  LBD   LBA PSH  \
# 0       3.40   5.00  1.75  3.35  4.20  1.85  3.2  3.5  1.80  3.3  3.75 NaN
# 1       3.20   3.60  1.80  3.30  3.95  1.90  3.2  3.5  1.90  3.2  3.50 NaN
# 2       3.30   2.75  2.40  3.30  2.55  2.60  3.1  2.3  2.50  3.2  2.50 NaN
# 3       3.75   7.50  1.40  4.00  6.80  1.40  3.9  6.0  1.44  3.6  6.50 NaN
# 4       3.50   1.65  5.00  3.50  1.60  4.00  3.3  1.7  4.00  3.4  1.72 NaN
# ...      ...    ...   ...   ...   ...   ...  ...  ...   ...  ...   ...  ..
# 25974    NaN    NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN NaN
# 25975    NaN    NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN NaN
# 25976    NaN    NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN NaN
# 25977    NaN    NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN NaN
# 25978    NaN    NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN NaN
#
#       PSD PSA   WHH   WHD   WHA   SJH  SJD   SJA   VCH   VCD   VCA   GBH  \
# 0     NaN NaN  1.70  3.30  4.33  1.90  3.3  4.00  1.65  3.40  4.50  1.78
# 1     NaN NaN  1.83  3.30  3.60  1.95  3.3  3.80  2.00  3.25  3.25  1.85
# 2     NaN NaN  2.50  3.25  2.40  2.63  3.3  2.50  2.35  3.25  2.65  2.50
# 3     NaN NaN  1.44  3.75  6.00  1.44  4.0  7.50  1.45  3.75  6.50  1.50
# 4     NaN NaN  4.20  3.40  1.70  4.50  3.5  1.73  4.50  3.40  1.65  4.50
# ...    ..  ..   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 25974 NaN NaN   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 25975 NaN NaN   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 25976 NaN NaN   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 25977 NaN NaN   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 25978 NaN NaN   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN
#
#         GBD   GBA   BSH   BSD   BSA
# 0      3.25  4.00  1.73  3.40  4.20
# 1      3.25  3.75  1.91  3.25  3.60
# 2      3.20  2.50  2.30  3.20  2.75
# 3      3.75  5.50  1.44  3.75  6.50
# 4      3.50  1.65  4.75  3.30  1.67
# ...     ...   ...   ...   ...   ...
# 25974   NaN   NaN   NaN   NaN   NaN
# 25975   NaN   NaN   NaN   NaN   NaN
# 25976   NaN   NaN   NaN   NaN   NaN
# 25977   NaN   NaN   NaN   NaN   NaN
# 25978   NaN   NaN   NaN   NaN   NaN
#
# [25979 rows x 115 columns]

# %% [markdown]
# ## Question 6: Select match data includes league and country information
#
# The Match table has relation with:
#  - Country table by country_id
#  - League table by League_id
#
# Use the join sql statement to join 3 tables.

# %%
result_6 = pd.read_sql("""SELECT m.id, m.season, m.stage, m.date,
                                 m.home_team_goal,
                                 m.away_team_goal,
                                 l.name AS league,
                                 c.name AS country
                            FROM Match AS m
                            JOIN League AS l
                              ON m.league_id = l.id
                            JOIN Country AS c
                              ON m.country_id = c.id;""", conn)
result_6
# Out:
#           id     season  stage                 date  home_team_goal  \
# 0          1  2008/2009      1  2008-08-17 00:00:00               1
# 1          2  2008/2009      1  2008-08-16 00:00:00               0
# 2          3  2008/2009      1  2008-08-16 00:00:00               0
# 3          4  2008/2009      1  2008-08-17 00:00:00               5
# 4          5  2008/2009      1  2008-08-16 00:00:00               1
# ...      ...        ...    ...                  ...             ...
# 25974  25975  2015/2016      9  2015-09-22 00:00:00               1
# 25975  25976  2015/2016      9  2015-09-23 00:00:00               1
# 25976  25977  2015/2016      9  2015-09-23 00:00:00               2
# 25977  25978  2015/2016      9  2015-09-22 00:00:00               0
# 25978  25979  2015/2016      9  2015-09-23 00:00:00               4
#
#        away_team_goal                    league      country
# 0                   1    Belgium Jupiler League      Belgium
# 1                   0    Belgium Jupiler League      Belgium
# 2                   3    Belgium Jupiler League      Belgium
# 3                   0    Belgium Jupiler League      Belgium
# 4                   3    Belgium Jupiler League      Belgium
# ...               ...                       ...          ...
# 25974               0  Switzerland Super League  Switzerland
# 25975               2  Switzerland Super League  Switzerland
# 25976               0  Switzerland Super League  Switzerland
# 25977               0  Switzerland Super League  Switzerland
# 25978               3  Switzerland Super League  Switzerland
#
# [25979 rows x 8 columns]

# %% [markdown]
# ## Question 7: Get number of match by each league including league name, order the number of match by descending

# %%
result_7 = pd.read_sql("""SELECT m.league_id,
                                 l.name AS league,
                                 COUNT(*) AS total_match
                            FROM Match AS m
                            JOIN League AS l
                              ON m.league_id = l.id
                           GROUP BY m.league_id
                           ORDER BY total_match DESC;""", conn)
result_7
# Out:
#     league_id                    league  total_match
# 0       21518           Spain LIGA BBVA         3040
# 1        4769            France Ligue 1         3040
# 2        1729    England Premier League         3040
# 3       10257             Italy Serie A         3017
# 4       13274    Netherlands Eredivisie         2448
# 5        7809     Germany 1. Bundesliga         2448
# 6       17642  Portugal Liga ZON Sagres         2052
# 7       15722        Poland Ekstraklasa         1920
# 8       19694   Scotland Premier League         1824
# 9           1    Belgium Jupiler League         1728
# 10      24558  Switzerland Super League         1422

# %% [markdown]
# ## Question 8: Get total goal of home team and away team in each league
# - use Group By statement

# %%
result_8 = pd.read_sql("""SELECT m.league_id,
                                 l.name AS league,
                                 SUM(m.home_team_goal) AS total_home_team_goal,
                                 SUM(m.away_team_goal) AS total_away_team_goal
                            FROM Match AS m
                            JOIN League AS l
                              ON m.league_id = l.id
                           GROUP BY m.league_id;""", conn)
result_8
# Out:
#     league_id                    league  total_home_team_goal  \
# 0           1    Belgium Jupiler League                  2781
# 1        1729    England Premier League                  4715
# 2        4769            France Ligue 1                  4265
# 3        7809     Germany 1. Bundesliga                  3982
# 4       10257             Italy Serie A                  4528
# 5       13274    Netherlands Eredivisie                  4357
# 6       15722        Poland Ekstraklasa                  2678
# 7       17642  Portugal Liga ZON Sagres                  2890
# 8       19694   Scotland Premier League                  2607
# 9       21518           Spain LIGA BBVA                  4959
# 10      24558  Switzerland Super League                  2365
#
#     total_away_team_goal
# 0                   2060
# 1                   3525
# 2                   3162
# 3                   3121
# 4                   3367
# 5                   3185
# 6                   1978
# 7                   2311
# 8                   2197
# 9                   3453
# 10                  1801

# %% [markdown]
# ## Question 9: Select data from Team table

# %%
result_9 = pd.read_sql("SELECT * FROM Team;", conn)
result_9
# Out:
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 0        1         9987             673.0            KRC Genk             GEN
# 1        2         9993             675.0        Beerschot AC             BAC
# 2        3        10000           15005.0    SV Zulte-Waregem             ZUL
# 3        4         9994            2007.0    Sporting Lokeren             LOK
# 4        5         9984            1750.0   KSV Cercle Brugge             CEB
# ..     ...          ...               ...                 ...             ...
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG
#
# [299 rows x 5 columns]

# %% [markdown]
# ## Question 10: Get top 20 teams with highest home goal
# - Use GROUP BY, LIMIT statement

# %%
result_10 = pd.read_sql("""SELECT t.id,
                                  t.team_long_name,
                                  t.team_short_name,
                                  SUM(m.home_team_goal) AS total_home_team_goal
                             FROM Team AS t
                             JOIN Match AS m
                               ON t.team_api_id = m.home_team_api_id
                            GROUP BY t.id
                            ORDER BY total_home_team_goal DESC
                            LIMIT 20;""", conn)
result_10
# Out:
#        id       team_long_name team_short_name  total_home_team_goal
# 0   43040       Real Madrid CF             REA                   505
# 1   43042         FC Barcelona             BAR                   495
# 2   39395               Celtic             CEL                   389
# 3   15617     FC Bayern Munich             BMU                   382
# 4   26556                  PSV             PSV                   370
# 5    3466      Manchester City             MCI                   365
# 6   26552                 Ajax             AJA                   360
# 7   49118             FC Basel             BAS                   344
# 8    3457    Manchester United             MUN                   338
# 9    3475              Chelsea             CHE                   333
# 10   9548  Paris Saint-Germain             PSG                   332
# 11  43053      Atlético Madrid             AMA                   321
# 12  35294           SL Benfica             BEN                   321
# 13  49117       BSC Young Boys              YB                   319
# 14  20522             Juventus             JUV                   307
# 15   3459              Arsenal             ARS                   306
# 16  20526               Napoli             NAP                   303
# 17  43035          Valencia CF             VAL                   299
# 18  20525                 Roma             ROM                   299
# 19  15620    Borussia Dortmund             DOR                   298

# %% [markdown]
# ## Question 11: Get top 20 teams with highest away goal
# - Use GROUP BY, LIMIT statement

# %%
result_11 = pd.read_sql("""SELECT t.id,
                                  t.team_long_name,
                                  t.team_short_name,
                                  SUM(m.away_team_goal) AS total_away_team_goal
                             FROM Team AS t
                             JOIN Match AS m
                               ON t.team_api_id = m.away_team_api_id
                            GROUP BY t.id
                            ORDER BY total_away_team_goal DESC
                            LIMIT 20;""", conn)
result_11
# Out:
#        id       team_long_name team_short_name  total_away_team_goal
# 0   43042         FC Barcelona             BAR                   354
# 1   43040       Real Madrid CF             REA                   338
# 2   39395               Celtic             CEL                   306
# 3   26552                 Ajax             AJA                   287
# 4   26556                  PSV             PSV                   282
# 5   49118             FC Basel             BAS                   275
# 6   15617     FC Bayern Munich             BMU                   271
# 7    3459              Arsenal             ARS                   267
# 8   15620    Borussia Dortmund             DOR                   253
# 9    3475              Chelsea             CHE                   250
# 10  35294           SL Benfica             BEN                   247
# 11  35283             FC Porto             POR                   246
# 12   3457    Manchester United             MUN                   244
# 13   3466      Manchester City             MCI                   241
# 14   3462            Liverpool             LIV                   237
# 15  20522             Juventus             JUV                   236
# 16   9548  Paris Saint-Germain             PSG                   236
# 17  20525                 Roma             ROM                   231
# 18  49124            FC Zürich             ZUR                   227
# 19   3470    Tottenham Hotspur             TOT                   226

# %% [markdown]
# ## Question 12: Get team long name with total of goal, order the total number by descending
#
# - Total of goal of a team is added up from both away and home games
# - Use UNION statement

# %%
result_12 = pd.read_sql("""SELECT t.team_long_name,
                                  SUM(m.goal) AS total_goal
                             FROM 
                                  (SELECT home_team_api_id AS team_api_id,      /* Get data from Match table returns the form: |team_api_id|goal| */
                                          home_team_goal AS goal                /* team_api_id column includes data: home_team_api_id, away_team_api_id */
                                     FROM Match                                 /* goal includes data: home_team_goal, away_team_goal */
                                     
                                    UNION ALL
                                    
                                   SELECT away_team_api_id AS team_api_id,
                                          away_team_goal AS goal
                                     FROM Match) AS m
                             JOIN Team AS t
                               ON t.team_api_id = m.team_api_id
                            GROUP BY t.id
                            ORDER BY total_goal DESC;""", conn)
result_12
# Out:
#        team_long_name  total_goal
# 0        FC Barcelona         849
# 1      Real Madrid CF         843
# 2              Celtic         695
# 3    FC Bayern Munich         653
# 4                 PSV         652
# ..                ...         ...
# 294           Amadora          26
# 295          Trofense          25
# 296      FC Dordrecht          24
# 297        Córdoba CF          22
# 298  AC Arles-Avignon          21
#
# [299 rows x 2 columns]

# %% [markdown]
# ## Question 13: Get team long name with total of matches, order the total number by descending

# %%
result_13 = pd.read_sql("""SELECT t.team_long_name,
                                  COUNT(*) AS total_match
                             FROM Match AS m
                             JOIN Team AS t
                               ON (t.team_api_id = m.home_team_api_id) 
                               OR (t.team_api_id = m.away_team_api_id) 
                            GROUP BY t.id
                            ORDER BY total_match DESC;""", conn)
result_13
# Out:
#                    team_long_name  total_match
# 0                       Málaga CF          304
# 1                 Atlético Madrid          304
# 2         Athletic Club de Bilbao          304
# 3                    RCD Espanyol          304
# 4                       Getafe CF          304
# ..                            ...          ...
# 294                  Portimonense           30
# 295                       Amadora           30
# 296                      Trofense           30
# 297  Termalica Bruk-Bet Nieciecza           30
# 298                     KAS Eupen           30
#
# [299 rows x 2 columns]

# %% [markdown]
# ## Question 14: Get numbers of win, lost and draw matches of each team
#
# - If a team has home goal > away goal , team is “win” in this match
# - If a team has home goal < away goal , team is “lost” in this match
# - If a team has home goal = away goal , team is “draw” in this match
# - Use Case When statement

# %%
result_14 = pd.read_sql("""SELECT t.id,
                                  t.team_long_name,
                                  t.team_short_name,
                                  SUM(CASE WHEN goal_difference > 0 THEN 1 END) AS total_win_match,
                                  SUM(CASE WHEN goal_difference < 0 THEN 1 END) AS total_lost_match,
                                  SUM(CASE WHEN goal_difference = 0 THEN 1 END) AS total_drawn_match,
                                  COUNT(*) AS total_match
                             FROM 
                                  (SELECT home_team_api_id AS team_api_id,                        /* Get data from Match table returns the form: |team_api_id|goal_difference| */
                                          (home_team_goal - away_team_goal) AS goal_difference    /* team_api_id column includes data: home_team_api_id, away_team_api_id */
                                     FROM Match                                                   /* goal_difference column includes data: (home_team_goal - away_team_goal), 
                                                                                                                                         (away_team_goal - home_team_goal) */
                                    UNION ALL  
                                    
                                   SELECT away_team_api_id AS team_api_id,
                                          (away_team_goal - home_team_goal) AS goal_difference
                                     FROM Match) AS m
                             JOIN Team AS t
                               ON (t.team_api_id = m.team_api_id) 
                            GROUP BY t.id;""", conn)
result_14
# Out:
#         id      team_long_name team_short_name  total_win_match  \
# 0        1            KRC Genk             GEN               97
# 1        2        Beerschot AC             BAC               40
# 2        3    SV Zulte-Waregem             ZUL               78
# 3        4    Sporting Lokeren             LOK               74
# 4        5   KSV Cercle Brugge             CEB               58
# ..     ...                 ...             ...              ...
# 294  49479       FC St. Gallen             GAL               72
# 295  49837             FC Thun             THU               71
# 296  50201         Servette FC             SER               20
# 297  50204  FC Lausanne-Sports             LAU               23
# 298  51606              Lugano             LUG                9
#
#      total_lost_match  total_drawn_match  total_match
# 0                  60                 55          212
# 1                  70                 42          152
# 2                  72                 62          212
# 3                  70                 68          212
# 4                  90                 34          182
# ..                ...                ...          ...
# 294                94                 50          216
# 295                75                 68          214
# 296                36                 14           70
# 297                65                 18          106
# 298                19                  8           36
#
# [299 rows x 7 columns]

# %% [markdown]
# ## Question 15: Get top 10 team with highest numbers of win matches

# %%
result_15 = pd.read_sql("""SELECT t.id,
                                  t.team_long_name,
                                  t.team_short_name,
                                  SUM(CASE WHEN goal_difference > 0 THEN 1 END) AS total_win_match
                             FROM 
                                  (SELECT home_team_api_id AS team_api_id,                        /* Get data from Match table returns the form: |team_api_id|goal_difference| */
                                          (home_team_goal - away_team_goal) AS goal_difference    /* team_api_id column includes data: home_team_api_id, away_team_api_id */
                                     FROM Match                                                   /* goal_difference column includes data: (home_team_goal - away_team_goal),
                                                                                                                                         (away_team_goal - home_team_goal) */
                                    UNION ALL   
                                    
                                   SELECT away_team_api_id AS team_api_id,
                                          (away_team_goal - home_team_goal) AS goal_difference
                                     FROM Match) AS m
                             JOIN Team AS t
                               ON (t.team_api_id = m.team_api_id) 
                            GROUP BY t.id
                            ORDER BY total_win_match DESC
                            LIMIT 10;""", conn)
result_15
# Out:
#       id     team_long_name team_short_name  total_win_match
# 0  43042       FC Barcelona             BAR              234
# 1  43040     Real Madrid CF             REA              228
# 2  39395             Celtic             CEL              218
# 3  15617   FC Bayern Munich             BMU              193
# 4   3457  Manchester United             MUN              192
# 5  20522           Juventus             JUV              189
# 6  35294         SL Benfica             BEN              185
# 7  35283           FC Porto             POR              183
# 8  26552               Ajax             AJA              181
# 9  49118           FC Basel             BAS              180

# %% [markdown]
# ## Question 16: Get percentage of each league to join the matches

# %%
result_16 = pd.read_sql("""SELECT *, ROUND(CAST(total_league_match AS float) / CAST(total_match AS float) * 100, 2) AS 'percentage (%)'
                             FROM  
                                  (SELECT m.league_id,                 /* Get data from Match table returns the form: |league_id|league|total_league_match|total_match| */
                                          l.name AS league, 
                                          COUNT(*) AS total_league_match,
                                          SUM(COUNT(*)) OVER () AS total_match
                                     FROM Match AS m
                                     JOIN League AS l
                                       ON m.league_id = l.id
                                    GROUP BY m.league_id);""", conn)
result_16
# Out:
#     league_id                    league  total_league_match  total_match  \
# 0           1    Belgium Jupiler League                1728        25979
# 1        1729    England Premier League                3040        25979
# 2        4769            France Ligue 1                3040        25979
# 3        7809     Germany 1. Bundesliga                2448        25979
# 4       10257             Italy Serie A                3017        25979
# 5       13274    Netherlands Eredivisie                2448        25979
# 6       15722        Poland Ekstraklasa                1920        25979
# 7       17642  Portugal Liga ZON Sagres                2052        25979
# 8       19694   Scotland Premier League                1824        25979
# 9       21518           Spain LIGA BBVA                3040        25979
# 10      24558  Switzerland Super League                1422        25979
#
#     percentage (%)
# 0             6.65
# 1            11.70
# 2            11.70
# 3             9.42
# 4            11.61
# 5             9.42
# 6             7.39
# 7             7.90
# 8             7.02
# 9            11.70
# 10            5.47

# %% [markdown]
# ## Question 17: Get percentage of score in each league

# %%
result_17 = pd.read_sql("""SELECT *, ROUND(CAST(total_league_goal AS float) / CAST(total_goal AS float) * 100, 2) AS 'percentage (%)'
                             FROM 
                                  (SELECT m.league_id,              /* Get data from Match table returns the form: |league_id|league|total_league_goal|total_goal| */
                                          l.name AS league,
                                          (SUM(m.home_team_goal) + SUM(m.away_team_goal)) AS total_league_goal,
                                          SUM(SUM(m.home_team_goal) + SUM(m.away_team_goal)) OVER () AS total_goal
                                     FROM Match AS m
                                     JOIN League AS l
                                       ON m.league_id = l.id
                                    GROUP BY m.league_id);""", conn)
result_17
# Out:
#     league_id                    league  total_league_goal  total_goal  \
# 0           1    Belgium Jupiler League               4841       70287
# 1        1729    England Premier League               8240       70287
# 2        4769            France Ligue 1               7427       70287
# 3        7809     Germany 1. Bundesliga               7103       70287
# 4       10257             Italy Serie A               7895       70287
# 5       13274    Netherlands Eredivisie               7542       70287
# 6       15722        Poland Ekstraklasa               4656       70287
# 7       17642  Portugal Liga ZON Sagres               5201       70287
# 8       19694   Scotland Premier League               4804       70287
# 9       21518           Spain LIGA BBVA               8412       70287
# 10      24558  Switzerland Super League               4166       70287
#
#     percentage (%)
# 0             6.89
# 1            11.72
# 2            10.57
# 3            10.11
# 4            11.23
# 5            10.73
# 6             6.62
# 7             7.40
# 8             6.83
# 9            11.97
# 10            5.93

# %% [markdown]
# ## Question 18: Get total numbers of goals for each league in each season

# %%
# Long data format
result_18 = pd.read_sql("""SELECT m.league_id,
                                  l.name AS league,
                                  m.season,
                                  (SUM(m.home_team_goal) + SUM(m.away_team_goal)) AS total_league_goal
                             FROM Match AS m
                             JOIN League AS l
                               ON m.league_id = l.id
                            GROUP BY m.league_id, m.season;""", conn)
result_18
# Out:
#     league_id                    league     season  total_league_goal
# 0           1    Belgium Jupiler League  2008/2009                855
# 1           1    Belgium Jupiler League  2009/2010                565
# 2           1    Belgium Jupiler League  2010/2011                635
# 3           1    Belgium Jupiler League  2011/2012                691
# 4           1    Belgium Jupiler League  2012/2013                703
# ..        ...                       ...        ...                ...
# 83      24558  Switzerland Super League  2011/2012                425
# 84      24558  Switzerland Super League  2012/2013                462
# 85      24558  Switzerland Super League  2013/2014                520
# 86      24558  Switzerland Super League  2014/2015                517
# 87      24558  Switzerland Super League  2015/2016                566
#
# [88 rows x 4 columns]

# %%
# Wide data format
result_18 = pd.read_sql("""SELECT league_id,
                                  league,
                                  MAX((CASE WHEN season = '2008/2009' THEN total_league_goal END)) AS '2008/2009',
                                  MAX((CASE WHEN season = '2009/2010' THEN total_league_goal END)) AS '2009/2010',
                                  MAX((CASE WHEN season = '2010/2011' THEN total_league_goal END)) AS '2010/2011',
                                  MAX((CASE WHEN season = '2011/2012' THEN total_league_goal END)) AS '2011/2012',
                                  MAX((CASE WHEN season = '2012/2013' THEN total_league_goal END)) AS '2012/2013',
                                  MAX((CASE WHEN season = '2013/2014' THEN total_league_goal END)) AS '2013/2014',
                                  MAX((CASE WHEN season = '2014/2015' THEN total_league_goal END)) AS '2014/2015',
                                  MAX((CASE WHEN season = '2015/2016' THEN total_league_goal END)) AS '2015/2016'
                            FROM 
                                 (SELECT m.league_id,         /* Get data from Match, League tables return the form: |league_id|league|season|total_league_goal| - long data format */
                                         l.name AS league,
                                         m.season,
                                         (SUM(m.home_team_goal) + SUM(m.away_team_goal)) AS total_league_goal
                                    FROM Match AS m
                                    JOIN League AS l
                                      ON m.league_id = l.id
                                   GROUP BY m.league_id, m.season)
                           GROUP BY league_id;""", conn)
result_18
# Out:
#     league_id                    league  2008/2009  2009/2010  2010/2011  \
# 0           1    Belgium Jupiler League        855        565        635
# 1        1729    England Premier League        942       1053       1063
# 2        4769            France Ligue 1        858        916        890
# 3        7809     Germany 1. Bundesliga        894        866        894
# 4       10257             Italy Serie A        988        992        955
# 5       13274    Netherlands Eredivisie        870        892        987
# 6       15722        Poland Ekstraklasa        524        532        578
# 7       17642  Portugal Liga ZON Sagres        552        601        584
# 8       19694   Scotland Premier League        548        585        584
# 9       21518           Spain LIGA BBVA       1101       1031       1042
# 10      24558  Switzerland Super League        540        599        537
#
#     2011/2012  2012/2013  2013/2014  2014/2015  2015/2016
# 0         691        703         30        668        694
# 1        1066       1063       1052        975       1026
# 2         956        967        933        947        960
# 3         875        898        967        843        866
# 4         925       1003       1035       1018        979
# 5         997        964        978        942        912
# 6         527        598        634        628        635
# 7         634        667        569        763        831
# 8         601        623        626        587        650
# 9        1050       1091       1045       1009       1043
# 10        425        462        520        517        566

# %% [markdown]
# ## Question 19: Get player attributes
#
# - Convert weight to kilogram
# - Convert height to meter
# - Calculuate bmi = ( (weight* 0.453592) / (height/100)^2)
# - Get Age of player

# %%
result_19 = pd.read_sql("""SELECT id,
                                  player_name,
                                  birthday,
                                  (DATE() - birthday) AS age,
                                  ROUND(weight * 0.453592, 2) AS 'weight (kg)',
                                  ROUND(height / 100, 2) AS 'height (m)',
                                  ROUND((weight * 0.453592) / (height * height / 10000), 2) AS bmi
                          FROM Player;""", conn)
result_19
# Out:
#           id          player_name             birthday  age  weight (kg)  \
# 0          1   Aaron Appindangoye  1992-02-29 00:00:00   30        84.82
# 1          2      Aaron Cresswell  1989-12-15 00:00:00   33        66.22
# 2          3          Aaron Doran  1991-05-13 00:00:00   31        73.94
# 3          4        Aaron Galindo  1982-05-08 00:00:00   40        89.81
# 4          5         Aaron Hughes  1979-11-08 00:00:00   43        69.85
# ...      ...                  ...                  ...  ...          ...
# 11055  11071       Zoumana Camara  1979-04-03 00:00:00   43        76.20
# 11056  11072         Zsolt Laczko  1986-12-18 00:00:00   36        79.83
# 11057  11073            Zsolt Low  1979-04-29 00:00:00   43        69.85
# 11058  11074  Zurab Khizanishvili  1981-10-06 00:00:00   41        78.02
# 11059  11075   Zvjezdan Misimovic  1982-06-05 00:00:00   40        79.83
#
#        height (m)    bmi
# 0            1.83  25.36
# 1            1.70  22.87
# 2            1.70  25.53
# 3            1.83  26.85
# 4            1.83  20.89
# ...           ...    ...
# 11055        1.83  22.78
# 11056        1.83  23.87
# 11057        1.80  21.48
# 11058        1.85  22.69
# 11059        1.80  24.55
#
# [11060 rows x 7 columns]

# %% [markdown]
# ## Question 20: Get oldest player

# %%
result_20 = pd.read_sql("""SELECT id,
                                  player_name,
                                  birthday,
                                  (DATE() - birthday) AS age,
                                  ROUND(weight * 0.453592, 2) AS 'weight (kg)',
                                  ROUND(height / 100, 2) AS 'height (m)',
                                  ROUND((weight * 0.453592) / (height * height / 10000), 2) AS bmi
                             FROM Player
                            WHERE birthday = (SELECT MIN(birthday) FROM Player);""", conn)
result_20
# Out:
#     id      player_name             birthday  age  weight (kg)  height (m)  \
# 0  290  Alberto Fontana  1967-01-23 00:00:00   55        73.03        1.85
#
#      bmi
# 0  21.24

# %% [markdown]
# ## Question 21: Get players who played highest number of matches

# %%
result_21 = pd.read_sql("""SELECT id, 
                                  player_name,
                                  birthday,
                                  age,
                                  weight AS 'weight (kg)',
                                  height AS 'height (m)',
                                  bmi,
                                  total_match
                             FROM  
                                  (SELECT p.id,           /* Get data from Player, Player_Attributes tables return the form: |id|player_name|birthday|age|weight|height|bmi|total_match|max_total_match| */
                                          p.player_name,
                                          p.birthday,
                                          (DATE() - p.birthday) AS age,
                                          ROUND(p.weight * 0.453592, 2) AS weight,
                                          ROUND(p.height / 100, 2) AS height,
                                          ROUND((p.weight * 0.453592) / (p.height * p.height / 10000), 2) AS bmi,
                                          COUNT(*) AS total_match,
                                          MAX(COUNT(*)) OVER() AS max_total_match
                                     FROM Player AS p
                                     JOIN Player_Attributes As a
                                       ON p.player_api_id = a.player_api_id
                                    GROUP BY p.id
                                    ORDER BY total_match DESC)
                             WHERE total_match = max_total_match;""", conn)
result_21
# Out:
#      id      player_name             birthday  age  weight (kg)  height (m)  \
# 0   396    Alessio Cerci  1987-07-23 00:00:00   35        78.02        1.80
# 1  9073  Roberto Pereyra  1991-01-07 00:00:00   31        77.11        1.83
#
#      bmi  total_match
# 0  23.99           56
# 1  23.06           56

# %% [markdown]
# ## Question 22: Get players who had overall_rating larger than 80

# %%
result_22 = pd.read_sql("""SELECT p.id,
                                  p.player_name,
                                  p.birthday,
                                  (DATE() - p.birthday) AS age,
                                  ROUND(p.weight * 0.453592, 2) AS 'weight (kg)',
                                  ROUND(p.height / 100, 2) AS 'height (m)',
                                  ROUND((p.weight * 0.453592) / (p.height * p.height / 10000), 2) AS bmi,
                                  a.overall_rating
                             FROM Player_Attributes AS a
                             JOIN Player As p
                               ON a.player_api_id = p.player_api_id
                            WHERE a.overall_rating > 80
                            GROUP BY p.id
                            ORDER BY a.overall_rating DESC;""", conn)
result_22
# Out:
#        id        player_name             birthday  age  weight (kg)  \
# 0    6176       Lionel Messi  1987-06-24 00:00:00   35        72.12
# 1    1995  Cristiano Ronaldo  1985-02-05 00:00:00   37        79.83
# 2    7867             Neymar  1992-02-05 00:00:00   30        68.04
# 3    6556       Manuel Neuer  1986-03-27 00:00:00   36        92.08
# 4    6377        Luis Suarez  1987-01-24 00:00:00   35        84.82
# ..    ...                ...                  ...  ...          ...
# 834   204    Afonso Alves,24  1981-01-30 00:00:00   41        73.94
# 835   170       Adrian Lopez  1988-01-08 00:00:00   34        73.03
# 836   148          Adil Rami  1985-12-27 00:00:00   37        88.00
# 837   142        Adem Ljajic  1991-09-29 00:00:00   31        73.94
# 838     8       Aaron Lennon  1987-04-16 00:00:00   35        63.05
#
#      height (m)    bmi  overall_rating
# 0          1.70  24.90              94
# 1          1.85  23.22              93
# 2          1.75  22.15              90
# 3          1.93  24.71              90
# 4          1.83  25.36              90
# ..          ...    ...             ...
# 834        1.85  21.51              81
# 835        1.83  21.84              81
# 836        1.91  24.25              81
# 837        1.83  22.11              81
# 838        1.65  23.13              81
#
# [839 rows x 8 columns]
